# %%
import pandas as pd
import json

with open("../data/raw/matches_raw.json", encoding="utf-8") as f:
    matches = json.load(f)
df = pd.DataFrame(matches)
df.describe()
# Out:
#        team1_goals  team2_goals  h2h_games_played  h2h_team1_wins  \
# count   230.000000   230.000000        230.000000      230.000000
# mean      1.626087     1.182609         26.121739        9.956522
# std       1.465533     1.179020         31.277361       12.553739
# min       0.000000     0.000000          1.000000        0.000000
# 25%       1.000000     0.000000          2.000000        1.000000
# 50%       1.000000     1.000000         18.000000        6.000000
# 75%       2.000000     2.000000         38.000000       13.000000
# max       7.000000     5.000000        198.000000       83.000000
#
#        h2h_team2_wins   h2h_draws  h2h_team1_scored  h2h_team2_scored  \
# count      230.000000  230.000000        230.000000        230.000000
# mean         9.769565    6.395652         36.952174         36.382609
# std         12.951166    7.875393         47.886350         47.964795
# min          0.000000    0.000000          0.000000          0.000000
# ...
